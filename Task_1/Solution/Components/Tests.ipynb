# %% [markdown]
# # Tests

# %%
import Imputation as Imputation
import Outlier_Detection_1D as Outlier_Detection_1D
import Outlier_Detection_ND as Outlier_Detection_ND
import Feature_Selection as Feature_Selection
import Normalisation as Normalisation
import data_fetching as data_fetching
import data_observations as data_observations

# CAREFUL:
# If you make changes to a custom module, you have to reload it, i.e rerun this cell
import importlib
importlib.reload(Imputation)
importlib.reload(Outlier_Detection_1D)
importlib.reload(Outlier_Detection_ND)
importlib.reload(Feature_Selection)
importlib.reload(Normalisation)
importlib.reload(data_fetching)
importlib.reload(data_observations)
# Out:
# <module 'data_observations' from '/home/jovyan/work/AML/Task_1/Solution/Components/data_observations.py'>

# %% [markdown]
# ## Importing test data

# %%
x_train, y_train = data_fetching.get_train_data()
x_test = data_fetching.get_test_data()

# %% [markdown]
# ## Normalisation

# %%
assert Normalisation.gaussian(x_train).shape == x_train.shape, "Gaussian: Bad return shape"

# %% [markdown]
# ## Imputation

# %%
assert Imputation.mean(x_train).shape == x_train.shape, "Mean: Bad return shape"
assert Imputation.median(x_train).shape == x_train.shape, "Median: Bad return shape"

# %% [markdown]
# ## Outlier Detection 1D

# %%
assert Outlier_Detection_1D.z_score(x_train).shape == x_train.shape, "Z_Score: Bad return shape"
assert Outlier_Detection_1D.z_score(x_train,x_extra=x_test).shape == x_train.shape, "Z_Score: Extra Data: Bad return shape"
# Out:
# X (1212, 832)
# X (1212, 832)

# %% [markdown]
# ## Outlier Detection ND

# %%
x_train_imp = Imputation.median(x_train)
assert Outlier_Detection_ND.mahalanobis_distance(x_train_imp,y_train)[0].shape[1] == x_train_imp.shape[1], "Z_Score: Bad return shape"

# %% [markdown]
# ## Feature Selection

# %%
Feature_Selection.drop_correlated(Outlier_Detection_1D.z_score(Normalisation.gaussian(x_train)),verbose=True,percent=0.9)
# assert drop_correlated
# Out:
# 56
#             x0        x1        x2        x3        x4        x5        x6  \
# 0     0.928000 -1.745407  0.497000 -0.576801  1.676983 -0.924964  1.922182
# 1     1.535117  1.274034       NaN -1.101386  0.318278  0.810082  0.832473
# 2     1.116752  1.161910 -0.337371 -1.779143 -0.797947 -0.911592 -0.077840
# 3     1.695776       NaN       NaN -1.631598 -0.577807 -0.574428  0.570073
# 4     0.386890 -0.807507  0.896542       NaN -0.057417 -1.696259 -0.156182
# ...        ...       ...       ...       ...       ...       ...       ...
# 1207 -0.140212  0.677547 -0.386378  0.980043  1.094354  0.818622  0.872723
# 1208 -0.218118 -1.457873  0.148039 -0.800444 -0.206745       NaN -0.033964
# 1209 -0.785394 -1.489300  0.019313  0.777972 -2.345854 -0.543166       NaN
# 1210       NaN -0.975043  1.242023  0.764193 -0.702899 -1.241936 -0.791015
# 1211 -1.007839 -0.518709  0.186348  0.821446 -0.457120  0.799428  0.451857
#
#             x7        x8        x9  ...      x521      x522      x523  \
# 0          NaN  1.467881 -0.672378  ...  1.028131 -1.027505 -0.353576
# 1    -1.542774  1.006017  0.931900  ... -0.775591  0.042107 -1.059602
# 2     0.302221  0.309946 -0.063730  ...  1.275274 -0.147728 -1.912959
# 3     1.764345  1.619512  0.816567  ... -0.467398  1.078808  1.442263
# 4     1.471527  0.632349 -1.012485  ...  0.089134  0.024113  1.353350
# ...        ...       ...       ...  ...       ...       ...       ...
# 1207       NaN  0.227134  0.393869  ...  2.213828       NaN  1.778380
# 1208  0.382358  1.104559  2.452700  ...  1.328511 -0.075480  1.220545
# 1209       NaN  0.922840  0.389256  ... -1.907717 -0.295146 -1.562921
# 1210  1.584648 -1.685240  0.143410  ...  0.629441 -0.037661  0.926901
# 1211 -0.242902  0.141218 -0.386898  ... -0.709000 -0.062455  1.034707
#
#           x524      x525      x526      x527      x528      x529      x530
# 0    -0.527188  0.340522 -0.532542  0.416239 -1.221167 -0.234232  0.043215
# 1    -1.549868 -1.937257  0.337486 -0.584946 -1.457911 -0.667601       NaN
# 2    -0.838055 -0.648695  0.698881 -0.431257  0.356481  1.788711 -0.456695
# 3    -0.110773  1.354672 -0.899887 -1.257886  0.357509  0.415235 -0.691756
# 4    -0.163465  1.350848 -1.590938       NaN  0.701455  1.072501 -0.697693
# ...        ...       ...       ...       ...       ...       ...       ...
# 1207  0.634999  0.145573  1.003158 -0.626321 -0.962100 -1.304393  0.068593
# 1208  1.277298 -0.010805  1.653153  1.298681 -0.272497 -1.231039 -0.352620
# 1209 -1.291266 -1.548274  2.422849       NaN -1.241299 -0.671531  0.721885
# 1210 -0.841410  0.575922  1.284319  0.000166  0.811071  0.345912  0.088116
# 1211  0.351438  0.100887       NaN  1.054889  1.141843 -0.282743 -1.643590
#
# [1212 rows x 500 columns]

# %%
Imputation.mean(Outlier_Detection_1D.z_score(Normalisation.gaussian(x_train)))
# Out:
#             x0        x1        x2        x3        x4        x5        x6  \
# 0     0.928000 -1.745407  0.497000 -0.576801  1.676983 -0.924964  1.922182
# 1     1.535117  1.274034 -0.010134 -1.101386  0.318278  0.810082  0.832473
# 2     1.116752  1.161910 -0.337371 -1.779143 -0.797947 -0.911592 -0.077840
# 3     1.695776 -0.005313 -0.010134 -1.631598 -0.577807 -0.574428  0.570073
# 4     0.386890 -0.807507  0.896542 -0.007980 -0.057417 -1.696259 -0.156182
# ...        ...       ...       ...       ...       ...       ...       ...
# 1207 -0.140212  0.677547 -0.386378  0.980043  1.094354  0.818622  0.872723
# 1208 -0.218118 -1.457873  0.148039 -0.800444 -0.206745 -0.004396 -0.033964
# 1209 -0.785394 -1.489300  0.019313  0.777972 -2.345854 -0.543166 -0.005419
# 1210 -0.004328 -0.975043  1.242023  0.764193 -0.702899 -1.241936 -0.791015
# 1211 -1.007839 -0.518709  0.186348  0.821446 -0.457120  0.799428  0.451857
#
#             x7        x8        x9  ...      x490      x491      x492  \
# 0    -0.003923  1.467881 -0.672378  ...  0.012659  2.166168  0.979032
# 1    -1.542774  1.006017  0.931900  ...  1.368994  0.733624 -0.574838
# 2     0.302221  0.309946 -0.063730  ...  0.378972 -0.006560 -0.821756
# 3     1.764345  1.619512  0.816567  ...  0.364211 -1.272805  0.656173
# 4     1.471527  0.632349 -1.012485  ... -0.322645  0.602805 -0.173663
# ...        ...       ...       ...  ...       ...       ...       ...
# 1207 -0.003923  0.227134  0.393869  ... -0.004855  0.332400  1.091498
# 1208  0.382358  1.104559  2.452700  ... -2.117049  0.739616  0.252900
# 1209 -0.003923  0.922840  0.389256  ...  1.639979 -0.011031  0.048728
# 1210  1.584648 -1.685240  0.143410  ... -0.458615  0.110819 -1.628472
# 1211 -0.242902  0.141218 -0.386898  ...  0.240701  0.192585 -1.403027
#
#           x493      x494      x495      x496      x497      x498      x499
# 0    -1.917161  0.278559 -0.007768 -0.811068 -0.008770 -0.664323  0.210170
# 1    -0.967095 -0.043180  0.999490 -0.490594 -2.036269 -0.004652 -1.446693
# 2    -1.240660 -2.211856  0.156591  0.211102 -0.234638 -0.643386 -0.120927
# 3    -0.346127 -0.439632 -0.431470  2.428015 -2.493576  1.976495  1.995388
# 4    -1.099151  1.372741 -1.534603  0.779599  1.344372  1.388271  1.621146
# ...        ...       ...       ...       ...       ...       ...       ...
# 1207 -0.650409  0.446204  1.383976 -0.581318  1.272215  1.764089  0.331878
# 1208 -0.700643  0.026268  0.510198  0.962892 -1.441709  0.948530  1.874875
# 1209 -0.761209  0.956371 -0.494101 -1.445772 -0.659304 -1.658968 -0.524615
# 1210 -0.361855 -1.169424 -0.839600  0.269343 -0.769317  1.602369  0.754927
# 1211  0.789681 -0.836057  0.904906 -0.221181 -0.008770  0.343576  0.147460
#
# [1212 rows x 500 columns]

# %%
Feature_Selection.drop_correlated(x_train,verbose=True)
# Out:
# 44
#              x0             x1            x2           x3            x4  \
# 0     10.891876  832442.812375  20585.544083  1028.369495  1.163780e+06
# 1     11.512994  832442.898114           NaN  1012.624877  1.028911e+06
# 2     11.052185  832442.896307  20585.512844  1003.953827  9.231756e+05
# 3     11.642076            NaN           NaN  1004.672084  9.459461e+05
# 4     10.407121  832442.831424  20585.557007          NaN  9.957182e+05
# ...         ...            ...           ...          ...           ...
# 1207   9.895208  832442.883343  20585.510774  1082.657477  1.107019e+06
# 1208   9.838322  832442.816133  20585.530631  1020.816077  9.834291e+05
# 1209   9.267322  832442.815687  20585.525811  1076.663108  7.651645e+05
# 1210        NaN  832442.826707  20585.564056  1076.359217  9.332198e+05
# 1211   9.070810  832442.841694  20585.531908  1077.977276  9.568525e+05
#
#              x5             x6            x7            x8             x9  \
# 0      9.199135  597900.477629           NaN  1.144294e+06  785176.201298
# 1     10.906408  597900.458612   8127.016078  1.099166e+06  785176.258299
# 2      9.212979  597900.426764  10738.092422  1.027863e+06  785176.223468
# 3      9.553420  597900.450367  13524.096973  1.168144e+06  785176.254867
# 4      8.419164  597900.423639  12894.065081  1.063199e+06  785176.190880
# ...         ...            ...           ...           ...            ...
# 1207  10.915545  597900.459438           NaN  1.020097e+06  785176.241638
# 1208        NaN  597900.428561  10842.043309  1.110318e+06  785176.275709
# 1209   9.579855            NaN           NaN  1.092330e+06  785176.241429
# 1210   8.863739  597900.402740  13121.042555  8.245987e+05  785176.231471
# 1211  10.894921  597900.446646   9947.064942  1.010069e+06  785176.209791
#
#       ...           x515        x516        x517          x518          x519  \
# 0     ...  100157.656193   94.760941  109.054645  10568.880640  11164.012408
# 1     ...            NaN  109.474675  104.526098  10373.981691   9893.922337
# 2     ...  100794.960295  113.643853  105.345986  10986.362310   8144.714352
# 3     ...  101706.711691  104.220384  108.461501  10808.500030   9011.458392
# 4     ...            NaN   91.577116  103.079245           NaN  11388.972952
# ...   ...            ...         ...         ...           ...           ...
# 1207  ...  104004.174331   99.908968  108.947083  10974.843362   9502.430931
# 1208  ...  108012.247415         NaN  103.778243  10241.174257   9852.793513
# 1209  ...  107769.821876   94.231779  105.486728  10467.586963  10802.558719
# 1210  ...  101597.115080   98.215188  108.044196  10262.250772   9391.090492
# 1211  ...  105455.424704   94.465442  108.967443  10501.507354  10295.168247
#
#              x520          x521           x522          x523          x524
# 0     1820.005668  1.100651e+06   89243.477861   8139.000909  1.029746e+06
# 1     2551.085616  9.297902e+05  100531.454699   7069.088547  1.006338e+06
# 2     1591.042723  1.122917e+06   98553.167441   5743.039517  1.019035e+06
# 3     2619.032297  9.603796e+05  110316.298986  11128.014742  1.047220e+06
# 4     3139.081896  1.013893e+06  100419.965750  10948.070933  1.045718e+06
# ...           ...           ...            ...           ...           ...
# 1207  2673.010610  1.209802e+06            NaN  11875.030845  1.074140e+06
# 1208  2792.039761  1.130332e+06   99431.804590  10595.001799  1.090097e+06
# 1209  2263.045896  8.161147e+05   97035.284569   6352.007190  1.009742e+06
# 1210  3138.067608  1.061575e+06   99905.470885  10101.032023  1.018929e+06
# 1211  2485.045001  9.365375e+05   99601.365747  10298.073849  1.062035e+06
#
# [1212 rows x 500 columns]

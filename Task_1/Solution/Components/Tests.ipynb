# %% [markdown]
# # Tests

# %% [markdown]
# ## Importing test data

# %%
import data_fetching
import imp
imp.reload(data_fetching)
x_train, y_train, x_test = data_fetching.get_data()
# Out:
# /home/jovyan/work/AML/Task_1/Solution/Components

# %% [markdown]
# ## Imputation

# %%
import Imputation

Imputation.impute()
#assert ... tests
# Out:
# Hi

# %% [markdown]
# ## Outlier Detection 1D

# %%
import Outlier_Detection_1D

assert Outlier_Detection_1D.z_score(x_train).shape() == x_train.shape()
#assert ... tests
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-c5d821db2d1a> in <module>
#       1 import Outlier_Detection_1D
#       2
# ----> 3 assert Outlier_Detection_1D.z_score(x_train).shape() == x_train.shape()
#       4 #assert ... tests
#
# NameError: name 'x_train' is not defined

# %% [markdown]
# ## Outlier Detection ND

# %% [markdown]
# ## Feature Selection

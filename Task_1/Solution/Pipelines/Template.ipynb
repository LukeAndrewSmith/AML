# %% [markdown]
# # Template Pipeline
# Normalisation&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# **-**
# Imputation 1&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# **Median**
# Outlier Detection&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# **Z Score**
# Imputation 2&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# **Median**
# Feature Selection&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# **Implicit to model**
# Model&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# **Lasso Regression**

# %% [markdown]
# ## Imports

# %%
# General
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# ML
from sklearn.linear_model import LinearRegression, Lasso, BayesianRidge, LassoCV, LassoLarsCV
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.model_selection import cross_val_score

# Custom
import sys,os
sys.path.append('/home/jovyan/work/AML/Task_1/Solution') # I would like a cleaner solution but works for now
import Components.Imputation as Imputation
import Components.Outlier_Detection_1D as Outlier_Detection_1D
import Components.Outlier_Detection_ND as Outlier_Detection_ND
import Components.Feature_Selection as Feature_Selection
import Components.Normalisation as Normalisation
import Components.data_fetching as data_fetching

# CAREFUL:
# If you make changes to a custom module, you have to reload it, i.e rerun this cell
import importlib
importlib.reload(Imputation)
importlib.reload(Outlier_Detection_1D)
importlib.reload(Outlier_Detection_ND)
importlib.reload(Feature_Selection)
importlib.reload(Normalisation)
importlib.reload(data_fetching)
# Out:
# <module 'Components.data_fetching' from '/home/jovyan/work/AML/Task_1/Solution/Components/data_fetching.py'>

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Import

# %%
X, y = data_fetching.get_train_data()
x_test = data_fetching.get_test_data()

# %%
### First imputation

# %%
missing_values = Imputation.missing_values_mask(X) # save which values were originally missing
X = Imputation.median(X)

# %% [markdown]
# ### Outlier Detection

# %%
X = Outlier_Detection_1D.z_score(X)
y = Outlier_Detection_1D.z_score(y)

# %%
### Second imputation

# %%
X = X.mask(missing_values)
X = Imputation.median(X,x_test)
y = Imputation.median(y)

# %% [markdown]
# ## Model Training

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=0)

# %% [markdown]
# ### Simple

# %%
#lasso = Lasso(normalize=False, max_iter=1000, alpha=15000).fit(x_train, y_train)
#lasso = LassoCV(normalize=False, max_iter=1000).fit(x_train, y_train)

print('Train Score:')
y_pred_train = lasso.predict(x_train)
train_score = r2_score(y_train, y_pred_train)
print(train_score)

print('Test Score')
y_pred_test = lasso.predict(x_test)
test_score = r2_score(y_test, y_pred_test)
print(test_score)
# Out:
# /opt/venv/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Train Score:
# 0.09739767422358236
# Test Score
# 0.17435265079299833

# %%
plt.hist(y_train.iloc[:,0].to_numpy(), bins='auto')
plt.title('Actual')
plt.show()

plt.hist(y_pred_train, bins='auto')
plt.title('Prediction')
plt.show()

# %%
plt.hist(y_test.iloc[:,0].to_numpy(), bins='auto')
plt.title('Actual')
plt.show()

plt.hist(y_pred_test, bins='auto')
plt.title('Prediction')
plt.show()

# %% [markdown]
# ### With Cross Validation

# %%
lasso = LassoLarsCV(normalize = False)
#lasso = LassoCV(normalize=True, max_iter=1000, selection=random, normalize=True)
#lasso = Lasso(normalize=False, max_iter=1000, alpha=15000)
scores = cross_val_score(lasso, X, np.ravel(y), cv=5, scoring='r2')
print(scores)
print(np.mean(scores))
# Out:
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 291 iterations, alpha=2.828e+03, previous alpha=1.862e+02, with an active set of 234 regressors.
#   ConvergenceWarning)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 288 iterations, alpha=4.408e+03, previous alpha=1.721e+02, with an active set of 231 regressors.
#   ConvergenceWarning)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 224 iterations, alpha=3.241e+03, previous alpha=3.610e+02, with an active set of 201 regressors.
#   ConvergenceWarning)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 404 iterations, alpha=1.186e+04, previous alpha=6.375e+01, with an active set of 307 regressors.
#   ConvergenceWarning)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 239 iterations, alpha=4.165e+03, previous alpha=2.535e+02, with an active set of 202 regressors.
#   ConvergenceWarning)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 322 iterations, alpha=1.170e+02, previous alpha=1.169e+02, with an active set of 249 regressors.
#   ConvergenceWarning)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 173 iterations, alpha=5.109e+03, previous alpha=7.247e+02, with an active set of 154 regressors.
#   ConvergenceWarning)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 323 iterations, alpha=1.436e+03, previous alpha=1.172e+02, with an active set of 266 regressors.
#   ConvergenceWarning)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 276 iterations, alpha=4.772e+03, previous alpha=1.849e+02, with an active set of 227 regressors.
#   ConvergenceWarning)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 263 iterations, alpha=2.043e+02, previous alpha=2.043e+02, with an active set of 228 regressors.
#   ConvergenceWarning)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 401 iterations, alpha=2.018e+04, previous alpha=5.485e+01, with an active set of 302 regressors.
#   ConvergenceWarning)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 174 iterations, alpha=4.832e+03, previous alpha=7.432e+02, with an active set of 163 regressors.
#   ConvergenceWarning)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 435 iterations, alpha=4.064e+03, previous alpha=3.747e+01, with an active set of 342 regressors.
#   ConvergenceWarning)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 289 iterations, alpha=8.445e+02, previous alpha=1.239e+02, with an active set of 254 regressors.
#   ConvergenceWarning)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 181 iterations, alpha=6.484e+02, previous alpha=6.329e+02, with an active set of 162 regressors.
#   ConvergenceWarning)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 292 iterations, alpha=1.679e+02, previous alpha=1.679e+02, with an active set of 239 regressors.
#   ConvergenceWarning)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 236 iterations, alpha=5.827e+03, previous alpha=3.038e+02, with an active set of 211 regressors.
#   ConvergenceWarning)
# [0.34666066 0.31957395 0.3324499  0.29805631 0.30946936]
# 0.32124203374865845

# %%
print(lasso.alpha)
coef = pd.DataFrame(lasso.coef_)
print(coef.where(coef!=0).count())
# Out:
# 15000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-46e5af17e9e2> in <module>
#       1 print(lasso.alpha)
# ----> 2 coef = pd.DataFrame(lasso.coef_)
#       3 print(coef.where(coef!=0).count())
#
# AttributeError: 'Lasso' object has no attribute 'coef_'

# %% [markdown]
# ## Final Prediction

# %%
#lasso_final = Lasso(normalize=False, max_iter=1000, alpha=15000).fit(X,y)
#lasso_final = LassoCV(normalize=False, max_iter=1000).fit(X,y)
lasso_final = LassoLarsCV(normalize = False).fit(X, y)

x_test = data_fetching.get_test_data()
x_test = Imputation.mean(x_test)
# Note: They said no outliers were introduced in x_test so no need to perform outlier detection

y_pred = lasso_final.predict(x_test)
plt.hist(y_pred)
# Out:
# /opt/venv/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 419 iterations, alpha=2.164e+03, previous alpha=3.993e+01, with an active set of 338 regressors.
#   ConvergenceWarning)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 339 iterations, alpha=5.946e+03, previous alpha=7.765e+01, with an active set of 280 regressors.
#   ConvergenceWarning)
# /opt/venv/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:604: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 224 iterations, alpha=6.486e+03, previous alpha=3.396e+02, with an active set of 195 regressors.
#   ConvergenceWarning)
# (array([  5.,  10.,  51., 135., 225., 179., 112.,  45.,  11.,   3.]),
#  array([51.12098913, 54.96955691, 58.81812469, 62.66669247, 66.51526025,
#         70.36382804, 74.21239582, 78.0609636 , 81.90953138, 85.75809916,
#         89.60666694]),
#  <BarContainer object of 10 artists>)

# %%
y_pred_pd = pd.DataFrame(data=y_pred, columns=["y"])
y_pred_pd.to_csv('../../Predictions/template_2.csv', index_label='id')

# %%
coef = pd.DataFrame(lasso_final.coef_)
print(coef.where(coef!=0).count())

print("alpha")
print(lasso_final.alpha_)
# Out:
# 0    61
# dtype: int64
# alpha
# 6660.004780217947

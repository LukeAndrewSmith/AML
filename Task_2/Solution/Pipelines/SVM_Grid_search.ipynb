# %% [markdown]
# ## Imports

# %%
# !pip install jupyternotify
# %load_ext jupyternotify
# Out:
# Requirement already satisfied: jupyternotify in /opt/conda/lib/python3.7/site-packages (0.1.15)
# Requirement already satisfied: jupyter in /opt/conda/lib/python3.7/site-packages (from jupyternotify) (1.0.0)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.7/site-packages (from jupyternotify) (7.18.1)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.7/site-packages (from jupyter->jupyternotify) (7.5.1)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.7/site-packages (from jupyter->jupyternotify) (5.3.4)
# Requirement already satisfied: qtconsole in /opt/conda/lib/python3.7/site-packages (from jupyter->jupyternotify) (4.7.7)
# Requirement already satisfied: jupyter-console in /opt/conda/lib/python3.7/site-packages (from jupyter->jupyternotify) (6.2.0)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.7/site-packages (from jupyter->jupyternotify) (5.6.1)
# Requirement already satisfied: notebook in /opt/conda/lib/python3.7/site-packages (from jupyter->jupyternotify) (6.1.4)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.7/site-packages (from ipython->jupyternotify) (4.4.2)
# Requirement already satisfied: traitlets>=4.2 in /opt/conda/lib/python3.7/site-packages (from ipython->jupyternotify) (5.0.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from ipython->jupyternotify) (3.0.8)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.7/site-packages (from ipython->jupyternotify) (2.7.1)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/lib/python3.7/site-packages (from ipython->jupyternotify) (49.6.0.post20201009)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.7/site-packages (from ipython->jupyternotify) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in /opt/conda/lib/python3.7/site-packages (from ipython->jupyternotify) (0.17.1)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.7/site-packages (from ipython->jupyternotify) (0.2.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /opt/conda/lib/python3.7/site-packages (from ipython->jupyternotify) (4.8.0)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/conda/lib/python3.7/site-packages (from ipywidgets->jupyter->jupyternotify) (5.0.7)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/conda/lib/python3.7/site-packages (from ipywidgets->jupyter->jupyternotify) (3.5.1)
# Requirement already satisfied: jupyter-client in /opt/conda/lib/python3.7/site-packages (from ipykernel->jupyter->jupyternotify) (6.1.7)
# Requirement already satisfied: tornado>=4.2 in /opt/conda/lib/python3.7/site-packages (from ipykernel->jupyter->jupyternotify) (6.0.4)
# Requirement already satisfied: pyzmq>=17.1 in /opt/conda/lib/python3.7/site-packages (from qtconsole->jupyter->jupyternotify) (19.0.2)
# Requirement already satisfied: qtpy in /opt/conda/lib/python3.7/site-packages (from qtconsole->jupyter->jupyternotify) (1.9.0)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.7/site-packages (from qtconsole->jupyter->jupyternotify) (4.6.3)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.7/site-packages (from qtconsole->jupyter->jupyternotify) (0.2.0)
# Requirement already satisfied: jinja2>=2.4 in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter->jupyternotify) (2.11.2)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter->jupyternotify) (0.3)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter->jupyternotify) (3.2.1)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter->jupyternotify) (0.4.4)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter->jupyternotify) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter->jupyternotify) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter->jupyternotify) (1.4.2)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.7/site-packages (from notebook->jupyter->jupyternotify) (20.1.0)
# Requirement already satisfied: Send2Trash in /opt/conda/lib/python3.7/site-packages (from notebook->jupyter->jupyternotify) (1.5.0)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.7/site-packages (from notebook->jupyter->jupyternotify) (0.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.7/site-packages (from notebook->jupyter->jupyternotify) (0.9.1)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyternotify) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/conda/lib/python3.7/site-packages (from jedi>=0.10->ipython->jupyternotify) (0.7.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.7/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython->jupyternotify) (0.6.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->jupyternotify) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/lib/python3.7/site-packages (from jupyter-client->ipykernel->jupyter->jupyternotify) (2.8.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from jinja2>=2.4->nbconvert->jupyter->jupyternotify) (1.1.1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert->jupyter->jupyternotify) (0.5.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert->jupyter->jupyternotify) (20.4)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert->jupyter->jupyternotify) (1.15.0)
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from argon2-cffi->notebook->jupyter->jupyternotify) (1.14.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->jupyternotify) (2.0.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->jupyternotify) (20.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->jupyternotify) (0.17.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->bleach->nbconvert->jupyter->jupyternotify) (2.4.7)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->jupyternotify) (2.20)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->jupyternotify) (3.3.0)

# %%
# General
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# ML
from sklearn.metrics import balanced_accuracy_score
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import balanced_accuracy_score

# Custom
import sys,os
sys.path.append( '.' )
sys.path.append( '..' )
import Components.Outlier_Detection as Outlier_Detection
import Components.Feature_Selection as Feature_Selection
import Components.Normalisation as Normalisation
import Components.data_fetching as data_fetching
import Components.Data_Augmentation as Data_Augmentation
import Components.wrapper as wrapper


# CAREFUL:
# If you make changes to a custom module, you have to reload it, i.e rerun this cell
import importlib
importlib.reload(Data_Augmentation)
importlib.reload(Outlier_Detection)
importlib.reload(Feature_Selection)
importlib.reload(Normalisation)
importlib.reload(data_fetching)
importlib.reload(wrapper)
# Out:
# <module 'Components.wrapper' from '../Components/wrapper.py'>

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Data Import

# %%
x_train, y_train = data_fetching.get_train_data()
x_test = data_fetching.get_test_data()

# %% [markdown]
# ## Model

# %% [markdown]
# ### Pipeline Setup

# %%
# we need: -scaling transformer -weighted loss function -multi-class model 
pipe = Pipeline([('scaling',StandardScaler()),
                 ('classification',
                  SVC(C=1.0,kernel='rbf',gamma='scale',shrinking=True,cache_size=1000,class_weight='balanced'))
                ])

# %% [markdown]
# ### Grid search

# %%
# %%notify
# C_range = np.logspace(-3, 3, 7)
# gamma_range = np.logspace(-3, 3, 7)
# parameters = [{'classification__kernel': ['rbf'], 'classification__gamma': gamma_range,'classification__C': C_range},
#               {'classification__kernel': ['linear'], 'classification__C': C_range},
#               {'classification__kernel': ['poly'], 'classification__C':C_range, 'classification__degree':[2,3,4,5]},
#               {'classification__kernel':['sigmoid'],'classification__C':C_range}
#              ]
#
# clf = GridSearchCV(pipe, parameters,cv=10,n_jobs=16,scoring='balanced_accuracy')
# clf.fit(x_train, np.ravel(y_train))
#
# # View The Best Parameters
# print(clf.best_params_)
# Out:
# {'classification__C': 0.001, 'classification__kernel': 'linear'}

# %%
print(clf.best_score_)
# Out:
# 0.6962037037037037

# %%
results = pd.DataFrame(clf.cv_results_)

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None, "display.max_colwidth",200) 
results[["params","mean_test_score"]]
# Out:
#                                                                                              params  \
# 0     {'classification__C': 0.001, 'classification__gamma': 0.001, 'classification__kernel': 'rbf'}
# 1      {'classification__C': 0.001, 'classification__gamma': 0.01, 'classification__kernel': 'rbf'}
# 2       {'classification__C': 0.001, 'classification__gamma': 0.1, 'classification__kernel': 'rbf'}
# 3       {'classification__C': 0.001, 'classification__gamma': 1.0, 'classification__kernel': 'rbf'}
# 4      {'classification__C': 0.001, 'classification__gamma': 10.0, 'classification__kernel': 'rbf'}
# 5     {'classification__C': 0.001, 'classification__gamma': 100.0, 'classification__kernel': 'rbf'}
# 6    {'classification__C': 0.001, 'classification__gamma': 1000.0, 'classification__kernel': 'rbf'}
# 7      {'classification__C': 0.01, 'classification__gamma': 0.001, 'classification__kernel': 'rbf'}
# 8       {'classification__C': 0.01, 'classification__gamma': 0.01, 'classification__kernel': 'rbf'}
# 9        {'classification__C': 0.01, 'classification__gamma': 0.1, 'classification__kernel': 'rbf'}
# 10       {'classification__C': 0.01, 'classification__gamma': 1.0, 'classification__kernel': 'rbf'}
# 11      {'classification__C': 0.01, 'classification__gamma': 10.0, 'classification__kernel': 'rbf'}
# 12     {'classification__C': 0.01, 'classification__gamma': 100.0, 'classification__kernel': 'rbf'}
# 13    {'classification__C': 0.01, 'classification__gamma': 1000.0, 'classification__kernel': 'rbf'}
# 14      {'classification__C': 0.1, 'classification__gamma': 0.001, 'classification__kernel': 'rbf'}
# 15       {'classification__C': 0.1, 'classification__gamma': 0.01, 'classification__kernel': 'rbf'}
# 16        {'classification__C': 0.1, 'classification__gamma': 0.1, 'classification__kernel': 'rbf'}
# 17        {'classification__C': 0.1, 'classification__gamma': 1.0, 'classification__kernel': 'rbf'}
# 18       {'classification__C': 0.1, 'classification__gamma': 10.0, 'classification__kernel': 'rbf'}
# 19      {'classification__C': 0.1, 'classification__gamma': 100.0, 'classification__kernel': 'rbf'}
# 20     {'classification__C': 0.1, 'classification__gamma': 1000.0, 'classification__kernel': 'rbf'}
# 21      {'classification__C': 1.0, 'classification__gamma': 0.001, 'classification__kernel': 'rbf'}
# 22       {'classification__C': 1.0, 'classification__gamma': 0.01, 'classification__kernel': 'rbf'}
# 23        {'classification__C': 1.0, 'classification__gamma': 0.1, 'classification__kernel': 'rbf'}
# 24        {'classification__C': 1.0, 'classification__gamma': 1.0, 'classification__kernel': 'rbf'}
# 25       {'classification__C': 1.0, 'classification__gamma': 10.0, 'classification__kernel': 'rbf'}
# 26      {'classification__C': 1.0, 'classification__gamma': 100.0, 'classification__kernel': 'rbf'}
# 27     {'classification__C': 1.0, 'classification__gamma': 1000.0, 'classification__kernel': 'rbf'}
# 28     {'classification__C': 10.0, 'classification__gamma': 0.001, 'classification__kernel': 'rbf'}
# 29      {'classification__C': 10.0, 'classification__gamma': 0.01, 'classification__kernel': 'rbf'}
# 30       {'classification__C': 10.0, 'classification__gamma': 0.1, 'classification__kernel': 'rbf'}
# 31       {'classification__C': 10.0, 'classification__gamma': 1.0, 'classification__kernel': 'rbf'}
# 32      {'classification__C': 10.0, 'classification__gamma': 10.0, 'classification__kernel': 'rbf'}
# 33     {'classification__C': 10.0, 'classification__gamma': 100.0, 'classification__kernel': 'rbf'}
# 34    {'classification__C': 10.0, 'classification__gamma': 1000.0, 'classification__kernel': 'rbf'}
# 35    {'classification__C': 100.0, 'classification__gamma': 0.001, 'classification__kernel': 'rbf'}
# 36     {'classification__C': 100.0, 'classification__gamma': 0.01, 'classification__kernel': 'rbf'}
# 37      {'classification__C': 100.0, 'classification__gamma': 0.1, 'classification__kernel': 'rbf'}
# 38      {'classification__C': 100.0, 'classification__gamma': 1.0, 'classification__kernel': 'rbf'}
# 39     {'classification__C': 100.0, 'classification__gamma': 10.0, 'classification__kernel': 'rbf'}
# 40    {'classification__C': 100.0, 'classification__gamma': 100.0, 'classification__kernel': 'rbf'}
# 41   {'classification__C': 100.0, 'classification__gamma': 1000.0, 'classification__kernel': 'rbf'}
# 42   {'classification__C': 1000.0, 'classification__gamma': 0.001, 'classification__kernel': 'rbf'}
# 43    {'classification__C': 1000.0, 'classification__gamma': 0.01, 'classification__kernel': 'rbf'}
# 44     {'classification__C': 1000.0, 'classification__gamma': 0.1, 'classification__kernel': 'rbf'}
# 45     {'classification__C': 1000.0, 'classification__gamma': 1.0, 'classification__kernel': 'rbf'}
# 46    {'classification__C': 1000.0, 'classification__gamma': 10.0, 'classification__kernel': 'rbf'}
# 47   {'classification__C': 1000.0, 'classification__gamma': 100.0, 'classification__kernel': 'rbf'}
# 48  {'classification__C': 1000.0, 'classification__gamma': 1000.0, 'classification__kernel': 'rbf'}
# 49                                 {'classification__C': 0.001, 'classification__kernel': 'linear'}
# 50                                  {'classification__C': 0.01, 'classification__kernel': 'linear'}
# 51                                   {'classification__C': 0.1, 'classification__kernel': 'linear'}
# 52                                   {'classification__C': 1.0, 'classification__kernel': 'linear'}
# 53                                  {'classification__C': 10.0, 'classification__kernel': 'linear'}
# 54                                 {'classification__C': 100.0, 'classification__kernel': 'linear'}
# 55                                {'classification__C': 1000.0, 'classification__kernel': 'linear'}
# 56      {'classification__C': 0.001, 'classification__degree': 2, 'classification__kernel': 'poly'}
# 57      {'classification__C': 0.001, 'classification__degree': 3, 'classification__kernel': 'poly'}
# 58      {'classification__C': 0.001, 'classification__degree': 4, 'classification__kernel': 'poly'}
# 59      {'classification__C': 0.001, 'classification__degree': 5, 'classification__kernel': 'poly'}
# 60       {'classification__C': 0.01, 'classification__degree': 2, 'classification__kernel': 'poly'}
# 61       {'classification__C': 0.01, 'classification__degree': 3, 'classification__kernel': 'poly'}
# 62       {'classification__C': 0.01, 'classification__degree': 4, 'classification__kernel': 'poly'}
# 63       {'classification__C': 0.01, 'classification__degree': 5, 'classification__kernel': 'poly'}
# 64        {'classification__C': 0.1, 'classification__degree': 2, 'classification__kernel': 'poly'}
# 65        {'classification__C': 0.1, 'classification__degree': 3, 'classification__kernel': 'poly'}
# 66        {'classification__C': 0.1, 'classification__degree': 4, 'classification__kernel': 'poly'}
# 67        {'classification__C': 0.1, 'classification__degree': 5, 'classification__kernel': 'poly'}
# 68        {'classification__C': 1.0, 'classification__degree': 2, 'classification__kernel': 'poly'}
# 69        {'classification__C': 1.0, 'classification__degree': 3, 'classification__kernel': 'poly'}
# 70        {'classification__C': 1.0, 'classification__degree': 4, 'classification__kernel': 'poly'}
# 71        {'classification__C': 1.0, 'classification__degree': 5, 'classification__kernel': 'poly'}
# 72       {'classification__C': 10.0, 'classification__degree': 2, 'classification__kernel': 'poly'}
# 73       {'classification__C': 10.0, 'classification__degree': 3, 'classification__kernel': 'poly'}
# 74       {'classification__C': 10.0, 'classification__degree': 4, 'classification__kernel': 'poly'}
# 75       {'classification__C': 10.0, 'classification__degree': 5, 'classification__kernel': 'poly'}
# 76      {'classification__C': 100.0, 'classification__degree': 2, 'classification__kernel': 'poly'}
# 77      {'classification__C': 100.0, 'classification__degree': 3, 'classification__kernel': 'poly'}
# 78      {'classification__C': 100.0, 'classification__degree': 4, 'classification__kernel': 'poly'}
# 79      {'classification__C': 100.0, 'classification__degree': 5, 'classification__kernel': 'poly'}
# 80     {'classification__C': 1000.0, 'classification__degree': 2, 'classification__kernel': 'poly'}
# 81     {'classification__C': 1000.0, 'classification__degree': 3, 'classification__kernel': 'poly'}
# 82     {'classification__C': 1000.0, 'classification__degree': 4, 'classification__kernel': 'poly'}
# 83     {'classification__C': 1000.0, 'classification__degree': 5, 'classification__kernel': 'poly'}
# 84                                {'classification__C': 0.001, 'classification__kernel': 'sigmoid'}
# 85                                 {'classification__C': 0.01, 'classification__kernel': 'sigmoid'}
# 86                                  {'classification__C': 0.1, 'classification__kernel': 'sigmoid'}
# 87                                  {'classification__C': 1.0, 'classification__kernel': 'sigmoid'}
# 88                                 {'classification__C': 10.0, 'classification__kernel': 'sigmoid'}
# 89                                {'classification__C': 100.0, 'classification__kernel': 'sigmoid'}
# 90                               {'classification__C': 1000.0, 'classification__kernel': 'sigmoid'}
#
#     mean_test_score
# 0          0.498241
# 1          0.341944
# 2          0.333333
# 3          0.333333
# 4          0.333333
# 5          0.333333
# 6          0.333333
# 7          0.626481
# 8          0.333333
# 9          0.333333
# 10         0.333333
# 11         0.333333
# 12         0.333333
# 13         0.333333
# 14         0.672593
# 15         0.396019
# 16         0.333333
# 17         0.333333
# 18         0.333333
# 19         0.333333
# 20         0.333333
# 21         0.691111
# 22         0.427037
# 23         0.333333
# 24         0.333333
# 25         0.333333
# 26         0.333333
# 27         0.333333
# 28         0.618704
# 29         0.410926
# 30         0.333333
# 31         0.333333
# 32         0.333333
# 33         0.333333
# 34         0.333333
# 35         0.613611
# 36         0.410926
# 37         0.333333
# 38         0.333333
# 39         0.333333
# 40         0.333333
# 41         0.333333
# 42         0.613611
# 43         0.410926
# 44         0.333333
# 45         0.333333
# 46         0.333333
# 47         0.333333
# 48         0.333333
# 49         0.696204
# 50         0.650556
# 51         0.621852
# 52         0.598241
# 53         0.598241
# 54         0.598241
# 55         0.598241
# 56         0.342778
# 57         0.353148
# 58         0.337037
# 59         0.379537
# 60         0.419630
# 61         0.505556
# 62         0.371019
# 63         0.387685
# 64         0.575926
# 65         0.630648
# 66         0.483981
# 67         0.503519
# 68         0.673333
# 69         0.657963
# 70         0.608056
# 71         0.617130
# 72         0.595000
# 73         0.601296
# 74         0.542130
# 75         0.568148
# 76         0.577500
# 77         0.575000
# 78         0.522407
# 79         0.538519
# 80         0.577685
# 81         0.575648
# 82         0.523148
# 83         0.539444
# 84         0.558796
# 85         0.599907
# 86         0.673981
# 87         0.664167
# 88         0.612222
# 89         0.604630
# 90         0.609352

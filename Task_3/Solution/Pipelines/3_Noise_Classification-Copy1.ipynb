# %%
# General
# ! pip install biosppy
# ! pip install neurokit2
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
import numpy as np

# ML - Processing, Metrics and Evaluation
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import f1_score
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import PCA
from imblearn.under_sampling import RandomOverSampler
# ML - Models
from sklearn.svm import SVC
import xgboost as xgb

# Custom
import sys,os
sys.path.append( '.' )
sys.path.append( '..' )
import Components.Normalisation as Normalisation
import Components.data_fetching as data_fetching
import Components.Feature_Engineering as Feature_Engineering


# CAREFUL:
# If you make changes to a custom module, you have to reload it, i.e rerun this cell
import importlib
importlib.reload(Normalisation)
importlib.reload(data_fetching)
importlib.reload(Feature_Engineering)
# Out:
# <module 'Components.Feature_Engineering' from '../Components/Feature_Engineering.py'>

# %% [markdown]
# # Data Fetching

# %%
X, y = data_fetching.get_engineered_train_data()
y = np.ravel(y)
#x_test = data_fetching.get_test_data()

# %% [markdown]
# # Data Processing

# %%
X = StandardScaler().fit_transform(X)

# %%
# TODO:
# 1. Separate noise class in y from others: set all classes in y < 3 to 0, and 3 to 1
# 2. Get X noise and X other classes separately
# 3. Generate new X noise samples to balance the classes
# 
y_noise = np.array([int(x > 2) for x in y])
y_noise_df = pd.DataFrame(y_noise, columns=['y'])
data = pd.concat([X, y_noise_df], axis = 1)

data_other = data.loc[data.y == 0]
data_noise = data.loc[data.y == 1]

X_other = data_other.drop(['y'], axis=1)
X_noise = data_noise.drop(['y'], axis=1)

print(X_other)
print(X_noise)
# Out:
#           0           1            2             3           4             5   \
# 0        0.0   68.630849  1703.000000  9.262802e+05  320.555556  30973.802469
# 1        1.0   61.726883  4091.680000  5.982348e+06  328.750000   9966.687500
# 2        2.0   84.916201  4084.166667  5.727385e+06  229.314286   4131.929796
# 3        3.0   67.432567  4591.500000  5.375670e+06  287.037037  11692.702332
# 4        4.0   59.495192  1515.857143  1.277013e+06  553.666667  73455.555556
# ...      ...         ...          ...           ...         ...           ...
# 5110  5110.0   47.716592  4245.136364  7.260853e+06  396.333333  54141.936508
# 5113  5113.0  100.600962  8503.159574  2.338257e+07  178.967742    125.364551
# 5114  5114.0   83.731456  4222.263158  5.604869e+06  216.027027    224.945215
# 5115  5115.0   72.080089  7115.640000  1.543488e+07  275.346939   5942.063307
# 5116  5116.0   80.042689  2948.230769  2.859654e+06  225.000000    261.440000
#
#                6             7           8             9   ...          62  \
# 0     1656.090909  8.901874e+05  287.600000   7399.240000  ... -197.400000
# 1     4188.962963  5.663943e+06  303.307692   3872.366864  ... -278.800000
# 2     4117.444444  5.717130e+06  229.400000   3534.982857  ...  -58.888889
# 3     4622.000000  5.374710e+06  287.037037  11852.480110  ... -537.357143
# 4     1765.555556  1.188104e+06  411.500000  49303.000000  ... -193.166667
# ...           ...           ...         ...           ...  ...         ...
# 5110  4175.173913  7.244609e+06  376.772727  29251.084711  ... -193.454545
# 5113  8528.414894  2.337890e+07  178.924731     87.037345  ...  104.680851
# 5114  4240.157895  5.587722e+06  214.972973     51.647918  ...  122.513514
# 5115  7151.340000  1.543874e+07  275.081633   5983.830071  ... -631.780000
# 5116  2976.423077  2.855210e+06  225.280000     88.921600  ...  123.846154
#
#                  63          64             65          66             67  \
# 0      59139.240000 -220.700000   58731.210000 -238.600000   58508.440000
# 1     155754.400000 -294.760000  156454.502400 -310.080000  156147.513600
# 2      47537.709877  -92.166667   46772.638889 -113.166667   47380.194444
# 3      47676.443878 -567.857143   47850.765306 -581.607143   47725.738520
# 4     283131.138889 -225.166667  279712.472222 -248.000000  287500.000000
# ...             ...         ...            ...         ...            ...
# 5110   62013.157025 -244.227273   56272.084711 -265.000000   54814.363636
# 5113      41.302399   79.425532      20.499774   65.457447       6.035423
# 5114      88.303871  104.432432      36.677867   95.162162      35.595325
# 5115  124568.611600 -667.480000  124209.689600 -685.520000  123818.889600
# 5116     238.822485   95.653846     233.226331   70.076923     182.840237
#
#               68             69   70   71
# 0    -261.300000   56908.810000  0.0  0.0
# 1    -320.640000  156293.830400  0.0  0.0
# 2    -124.805556   47025.378858  0.0  0.0
# 3    -605.714286   47565.204082  0.0  0.0
# 4    -347.000000  213629.000000  0.0  0.0
# ...          ...            ...  ...  ...
# 5110 -283.090909   54496.809917  0.0  0.0
# 5113   44.489362      25.292440  0.0  0.0
# 5114   42.756757     302.400292  0.0  0.0
# 5115 -709.300000  123299.570000  0.0  0.0
# 5116   47.384615     205.005917  0.0  0.0
#
# [4947 rows x 72 columns]
#           0          1            2             3           4             5   \
# 25      25.0  54.203806  4925.833333  6.062473e+06  361.652174  61198.748582
# 72      72.0  64.848173  2102.000000  1.195480e+06  298.333333   9239.388889
# 113    113.0  72.271566  4062.375000  5.653850e+06  265.483871  16620.056191
# 142    142.0  91.011236  2311.692308  9.582388e+05  250.833333  14452.638889
# 167    167.0  78.317621  1679.888889  6.377008e+05  344.000000  41795.000000
# ...      ...        ...          ...           ...         ...           ...
# 5025  5025.0  72.333849  1807.153846  8.609469e+05  246.666667    543.388889
# 5048  5048.0  95.559846  2089.222222  1.545966e+06  244.000000   7612.823529
# 5109  5109.0  95.824778  6548.485714  1.454841e+07  189.956522   1214.215501
# 5111  5111.0  71.953578  4461.400000  4.899304e+06  311.583333  13354.409722
# 5112  5112.0  70.249174  1653.400000  7.825630e+05  312.555556  11353.358025
#
#                6             7           8             9   ...          62  \
# 25    5062.038462  5.703667e+06  333.160000  50603.654400  ...  -48.458333
# 72    2119.071429  1.122427e+06  277.461538   7771.171598  ... -300.307692
# 113   4260.029412  5.869136e+06  249.515152  10517.280073  ...   37.781250
# 142   2090.000000  1.069013e+06  215.600000   7401.973333  ... -965.923077
# 167   1591.666667  6.768589e+05  251.181818   3520.694215  ... -290.444444
# ...           ...           ...         ...           ...  ...         ...
# 5025  1703.785714  1.004340e+06  251.923077    506.224852  ... -135.692308
# 5048  2167.909091  1.518497e+06  197.000000   4497.428571  ... -254.235294
# 5109  6576.828571  1.455882e+07  190.536232    690.451586  ...   79.642857
# 5111  4181.620690  5.074174e+06  277.250000  10770.616071  ... -827.120000
# 5112  1956.461538  9.833075e+05  279.083333   8635.909722  ... -237.800000
#
#                  63          64             65           66             67  \
# 25     45719.748264  -96.250000   46555.770833  -112.458333   43824.831597
# 72     44742.366864 -325.461538   47811.171598  -343.230769   47785.100592
# 113    24229.108398   14.250000   24012.750000    -3.750000   23398.625000
# 142   110258.840237 -997.153846  106983.514793 -1014.846154  109062.130178
# 167    30388.691358 -315.666667   31872.444444  -328.333333   31130.444444
# ...             ...         ...            ...          ...            ...
# 5025     310.674556 -160.384615     174.544379  -177.230769     153.100592
# 5048   56621.709343 -278.352941   55217.640138  -294.705882   54858.795848
# 5109    6078.115306   51.300000    5745.838571    34.714286    5755.375510
# 5111  197045.705600 -855.560000  197456.966400  -879.080000  199004.873600
# 5112   30493.960000 -269.800000   30058.360000  -289.900000   29197.490000
#
#                68             69   70   71
# 25    -127.500000   41726.416667  0.0  0.0
# 72    -361.769231   49417.562130  0.0  0.0
# 113    -17.187500   23342.464844  0.0  0.0
# 142  -1030.538462  107357.171598  0.0  0.0
# 167   -415.111111   44012.320988  0.0  0.0
# ...           ...            ...  ...  ...
# 5025  -189.000000     147.230769  0.0  0.0
# 5048  -309.117647   56346.927336  0.0  0.0
# 5109    15.042857    6062.698163  0.0  0.0
# 5111  -898.480000  194408.889600  0.0  0.0
# 5112  -320.000000   31545.600000  0.0  0.0
#
# [170 rows x 72 columns]

# %% [markdown]
# # Training

# %%
scaler = StandardScaler()
X_2 = scaler.fit_transform(X,y)

est = SVC(kernel='rbf')
cv_score = cross_val_score(est, X_2, y, cv=10, scoring='f1_micro')
print(cv_score)
print(np.mean(cv_score))
# Out:
# [0.66015625 0.67382812 0.66796875 0.65234375 0.67578125 0.65234375
#  0.65429688 0.66144814 0.68493151 0.67123288]
# 0.6654331274461839
